# %%
files=[
    r"C:\code\HFV\main.py",
    r"C:\code\HFV\logReader.py",
    r"C:\code\HFV\pages\utils.py",
    r"C:\code\HFV\pages\bond_level\page.py",
    r"C:\code\HFV\pages\bond_level\scripy.py",
    r"C:\code\HFV\pages\draw_cloud\page.py",
    r"C:\code\HFV\pages\draw_cloud\script.py",
    r"C:\code\HFV\pages\save_obtial\page.py",
    r"C:\code\HFV\pages\save_obtial\script.py",
    r"C:\code\HFV\server\server.py",
    r"C:\code\HFV\server\templates\home.html",
    r"C:\code\HFV\server\templates\help.html",
]
lines=[]
total=0
for file in files:
    with open(file,'r',encoding='utf-8') as f:
        num=len(f.readlines())
        lines.append([file,num])
        total+=num
lines
# Out:
# [['C:\\code\\HFV\\main.py', 183],
#  ['C:\\code\\HFV\\logReader.py', 217],
#  ['C:\\code\\HFV\\pages\\utils.py', 249],
#  ['C:\\code\\HFV\\pages\\bond_level\\page.py', 106],
#  ['C:\\code\\HFV\\pages\\bond_level\\scripy.py', 352],
#  ['C:\\code\\HFV\\pages\\draw_cloud\\page.py', 43],
#  ['C:\\code\\HFV\\pages\\draw_cloud\\script.py', 47],
#  ['C:\\code\\HFV\\pages\\save_obtial\\page.py', 45],
#  ['C:\\code\\HFV\\pages\\save_obtial\\script.py', 22],
#  ['C:\\code\\HFV\\server\\server.py', 80],
#  ['C:\\code\\HFV\\server\\templates\\home.html', 626],
#  ['C:\\code\\HFV\\server\\templates\\help.html', 74]]

# %%
total
# Out:
# 2044
