# %%
files=[
    r"C:\code\log-process\main.py",
    r"C:\code\log-process\logReader.py",
    r"C:\code\log-process\pages\utils.py",
    r"C:\code\log-process\pages\bond_level\page.py",
    r"C:\code\log-process\pages\bond_level\scripy.py",
    r"C:\code\log-process\pages\draw_cloud\page.py",
    r"C:\code\log-process\pages\draw_cloud\script.py",
    r"C:\code\log-process\pages\save_obtial\page.py",
    r"C:\code\log-process\pages\save_obtial\script.py",
    r"C:\code\log-process\server\server.py",
    r"C:\code\log-process\server\templates\home.html",
    r"C:\code\log-process\server\templates\help.html",
]
lines=[]
total=0
for file in files:
    with open(file,'r',encoding='utf-8') as f:
        num=len(f.readlines())
        lines.append([file,num])
        total+=num
lines
# Out:
# [['C:\\code\\log-process\\main.py', 175],
#  ['C:\\code\\log-process\\logReader.py', 212],
#  ['C:\\code\\log-process\\pages\\utils.py', 233],
#  ['C:\\code\\log-process\\pages\\bond_level\\page.py', 106],
#  ['C:\\code\\log-process\\pages\\bond_level\\scripy.py', 319],
#  ['C:\\code\\log-process\\pages\\draw_cloud\\page.py', 43],
#  ['C:\\code\\log-process\\pages\\draw_cloud\\script.py', 47],
#  ['C:\\code\\log-process\\pages\\save_obtial\\page.py', 50],
#  ['C:\\code\\log-process\\pages\\save_obtial\\script.py', 54],
#  ['C:\\code\\log-process\\server\\server.py', 80],
#  ['C:\\code\\log-process\\server\\templates\\home.html', 626],
#  ['C:\\code\\log-process\\server\\templates\\help.html', 74]]

# %%
total
# Out:
# 2019
