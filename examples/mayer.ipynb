# %%
import numpy as np
import pandas as pd
import re
import matplotlib.pyplot as plt

# %%
orders=np.load('orders1.npy')

# %%
plt.title('$C_4-C_6\ \pi\ bond order$')
plt.plot(np.arange(len(orders)),orders,marker='.')
plt.savefig('orders1.png',bbox_inches = 'tight',dpi=300)

# %%
orders
# Out:
# array([0.37105522, 0.3590375 , 0.32835646, 0.28828449, 0.24424333,
#        0.19799986, 0.15204265, 0.11354914, 0.09667439, 0.10064434,
#        0.11606582, 0.13768448, 0.16297266, 0.1908145 , 0.22065666,
#        0.25299846, 0.28812252, 0.32173127, 0.33752673, 0.32145698,
#        0.28785205, 0.25284808, 0.22060793, 0.19075175, 0.16295707,
#        0.13761306, 0.11602329, 0.1006635 , 0.0967636 , 0.11361443,
#        0.15204955, 0.19826859, 0.24422384, 0.28820251, 0.32834219,
#        0.35907816, 0.37110968])

# %%
orders[17],orders[18],orders[19]
# Out:
# (0.32173126814820663, 0.33752673080131107, 0.3214569837213349)
